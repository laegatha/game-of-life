# %%
import sys
sys.path.append('..')

from runner import Runner

# %%
Runner.run()
# Out:
# Number of rows: 20
# 20 rows
# Number of columns: 20
# 20 columns
# Table surface: height = 320 ; width = 320
# Number of iterations: 10
# 10 iterations
# Initial state
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 2
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 3
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 4
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 5
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 6
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 7
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 8
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 9
# Image(320, 320, ColorType.kBGRA_8888_ColorType, AlphaType.kPremul_AlphaType)
# State 10
# ...
